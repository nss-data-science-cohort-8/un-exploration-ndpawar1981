# %% [markdown]
# In this exercise, you'll redo the data gathering phase of the UNData Exploration project by using APIs instead of downloading csv files.
#
# You'll make use of the [World Bank Indicators API](https://datahelpdesk.worldbank.org/knowledgebase/articles/889392-about-the-indicators-api-documentation). Note that this API does not require an API key. Before attempting the exercise, it would be a good idea to skim through the Documentation page and to check out the [Basic Call Structure article](https://datahelpdesk.worldbank.org/knowledgebase/articles/898581)

# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Call the endpoint - https://api.worldbank.org/v2/country/all/indicator/NY.GDP.PCAP.PP.KD

# %%
#setting per page 341 so that we can pull all rows
endpoint = 'https://api.worldbank.org/v2/country/all/indicator/NY.GDP.PCAP.PP.KD'

params = {
    'format': 'json',
    "per_page" : 17024
}

response = requests.get(endpoint, params = params)

res = response.json()

# %%
#review keys
res[1][0].keys()
# Out:
# dict_keys(['indicator', 'country', 'countryiso3code', 'date', 'value', 'unit', 'obs_status', 'decimal'])

# %%
#review how to access data
res[1][0]
# Out:
# {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#   'value': 'GDP per capita, PPP (constant 2021 international $)'},
#  'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#  'countryiso3code': 'AFE',
#  'date': '2023',
#  'value': 4047.00703115979,
#  'unit': '',
#  'obs_status': '',
#  'decimal': 0}

# %%
gdp_ppp = pd.json_normalize(response.json()[1])

# %%
gdp_ppp.sample(10)
# Out:
#       countryiso3code  date         value unit obs_status  decimal  \
# 9598              KAZ  1961           NaN                        0
# 15929             TKM  1966           NaN                        0
# 8223              GUM  1992           NaN                        0
# 2006              MNA  2001   9626.812308                        0
# 16530             VUT  2005   2993.003868                        0
# 8190              GRD  1961           NaN                        0
# 1369              IDA  1998   2668.393453                        0
# 5257              KHM  2014   3621.718465                        0
# 9292              ITA  2011  50289.856294                        0
# 2578              PRE  2005   3406.427695                        0
#
#             indicator.id                                    indicator.value  \
# 9598   NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# 15929  NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# 8223   NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# 2006   NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# 16530  NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# 8190   NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# 1369   NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# 5257   NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# 9292   NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# 2578   NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
#
#       country.id                                      country.value
# 9598          KZ                                         Kazakhstan
# 15929         TM                                       Turkmenistan
# 8223          GU                                               Guam
# 2006          XQ  Middle East & North Africa (excluding high inc...
# 16530         VU                                            Vanuatu
# 8190          GD                                            Grenada
# 1369          XG                                          IDA total
# 5257          KH                                           Cambodia
# 9292          IT                                              Italy
# 2578          V1                           Pre-demographic dividend

# %% [markdown]
# Lets clean the columns

# %%
gdp_ppp = gdp_ppp.drop(columns=['countryiso3code','unit','obs_status','indicator.id','indicator.value','decimal'])

# %%
gdp_ppp = gdp_ppp.rename(columns={"date": "Year", "value": "GDP_Per_Capita","country.id":"country_id","country.value":"country"})

# %%
gdp_ppp
# Out:
#        Year  GDP_Per_Capita country_id                      country
# 0      2023     4047.007031         ZH  Africa Eastern and Southern
# 1      2022     4038.638689         ZH  Africa Eastern and Southern
# 2      2021     3994.171654         ZH  Africa Eastern and Southern
# 3      2020     3919.499230         ZH  Africa Eastern and Southern
# 4      2019     4130.057222         ZH  Africa Eastern and Southern
# ...     ...             ...        ...                          ...
# 17019  1964             NaN         ZW                     Zimbabwe
# 17020  1963             NaN         ZW                     Zimbabwe
# 17021  1962             NaN         ZW                     Zimbabwe
# 17022  1961             NaN         ZW                     Zimbabwe
# 17023  1960             NaN         ZW                     Zimbabwe
#
# [17024 rows x 4 columns]

# %% [markdown]
# ### Call the endpoint - https://api.worldbank.org/v2/country/all/indicator/SP.DYN.LE00.IN

# %%
endpoint = 'https://api.worldbank.org/v2/country/all/indicator/SP.DYN.LE00.IN'

params = {
    'format': 'json',
    "per_page" : 17024
}

response = requests.get(endpoint, params = params)

res = response.json()

# %%
#review data
res[1][0]
# Out:
# {'indicator': {'id': 'SP.DYN.LE00.IN',
#   'value': 'Life expectancy at birth, total (years)'},
#  'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#  'countryiso3code': 'AFE',
#  'date': '2023',
#  'value': None,
#  'unit': '',
#  'obs_status': '',
#  'decimal': 0}

# %%
df_le_birth_total = pd.json_normalize(response.json()[1])

# %%
df_le_birth_total[df_le_birth_total['country.id'] == 'GE']
# Out:
#      countryiso3code  date   value unit obs_status  decimal    indicator.id  \
# 7744             GEO  2023     NaN                        0  SP.DYN.LE00.IN
# 7745             GEO  2022  71.587                        0  SP.DYN.LE00.IN
# 7746             GEO  2021  71.694                        0  SP.DYN.LE00.IN
# 7747             GEO  2020  72.765                        0  SP.DYN.LE00.IN
# 7748             GEO  2019  73.470                        0  SP.DYN.LE00.IN
# ...              ...   ...     ...  ...        ...      ...             ...
# 7803             GEO  1964  62.333                        0  SP.DYN.LE00.IN
# 7804             GEO  1963  62.228                        0  SP.DYN.LE00.IN
# 7805             GEO  1962  61.858                        0  SP.DYN.LE00.IN
# 7806             GEO  1961  61.416                        0  SP.DYN.LE00.IN
# 7807             GEO  1960  61.222                        0  SP.DYN.LE00.IN
#
#                               indicator.value country.id country.value
# 7744  Life expectancy at birth, total (years)         GE       Georgia
# 7745  Life expectancy at birth, total (years)         GE       Georgia
# 7746  Life expectancy at birth, total (years)         GE       Georgia
# 7747  Life expectancy at birth, total (years)         GE       Georgia
# 7748  Life expectancy at birth, total (years)         GE       Georgia
# ...                                       ...        ...           ...
# 7803  Life expectancy at birth, total (years)         GE       Georgia
# 7804  Life expectancy at birth, total (years)         GE       Georgia
# 7805  Life expectancy at birth, total (years)         GE       Georgia
# 7806  Life expectancy at birth, total (years)         GE       Georgia
# 7807  Life expectancy at birth, total (years)         GE       Georgia
#
# [64 rows x 10 columns]

# %% [markdown]
# Lets rename the columns. Drop columns that are not needed.

# %%
df_le_birth_total = df_le_birth_total.drop(columns=['countryiso3code','unit','obs_status','indicator.id','indicator.value','decimal'])

# %%
df_le_birth_total = df_le_birth_total.rename(columns={"date": "Year", "value": "Life_expectancy","country.id":"country_id","country.value":"country"})

# %%
gdp_ppp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17024 entries, 0 to 17023
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            17024 non-null  object
#  1   GDP_Per_Capita  8175 non-null   float64
#  2   country_id      17024 non-null  object
#  3   country         17024 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 532.1+ KB

# %%
df_le_birth_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17024 entries, 0 to 17023
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             17024 non-null  object
#  1   Life_expectancy  16124 non-null  float64
#  2   country_id       17024 non-null  object
#  3   country          17024 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 532.1+ KB

# %% [markdown]
# ### Merge two data frames

# %%
gdp_le_df = gdp_ppp.merge(df_le_birth_total)

# %%
#look up some countries
gdp_le_df[gdp_le_df['country_id' ]== 'A5']
# Out:
# Empty DataFrame
# Columns: [Year, GDP_Per_Capita, country_id, country, Life_expectancy]
# Index: []

# %% [markdown]
# #### You can also get more information about the available countries (region, capital city, income level classification, etc.) by using the [Country API](https://datahelpdesk.worldbank.org/knowledgebase/articles/898590-country-api-queries). Use this API to pull in all available data. Merge this with your other datasets. Use this to now remove the rows that correspond to regions and not countries.

# %%
endpoint = 'https://api.worldbank.org/v2/country'

params = {
    'format': 'json',
    "per_page" : 296
}

response = requests.get(endpoint, params = params)

res = response.json()

# %%
country_code_list = []
country_name_List = []
country_capital_list = []
country_region_list = []
country_income_list =[]

for i in range(len(res[1])):
    country_code_list.append(res[1][i]['iso2Code'])
    country_name_List.append(res[1][i]['name'])
    country_capital_list.append(res[1][i]['capitalCity'])
    country_region_list.append(res[1][i]['region']['value'])
    country_income_list.append(res[1][i]['incomeLevel']['value'])

country_dict = {'country_id': country_code_list, 'country': country_name_List, 'capital': country_capital_list, 'region': country_region_list, 'income_level': country_income_list}
country_df = pd.DataFrame(country_dict)
   
print(country_df)
# Out:
#     country_id                                            country     capital  \
# 0           AW                                              Aruba  Oranjestad
# 1           ZH                        Africa Eastern and Southern
# 2           AF                                        Afghanistan       Kabul
# 3           A9                                             Africa
# 4           ZI                         Africa Western and Central
# ..         ...                                                ...         ...
# 291         A5  Sub-Saharan Africa excluding South Africa and ...
# 292         YE                                        Yemen, Rep.      Sana'a
# 293         ZA                                       South Africa    Pretoria
# 294         ZM                                             Zambia      Lusaka
# 295         ZW                                           Zimbabwe      Harare
#
#                          region         income_level
# 0    Latin America & Caribbean           High income
# 1                    Aggregates           Aggregates
# 2                    South Asia           Low income
# 3                    Aggregates           Aggregates
# 4                    Aggregates           Aggregates
# ..                          ...                  ...
# 291                  Aggregates           Aggregates
# 292  Middle East & North Africa           Low income
# 293         Sub-Saharan Africa   Upper middle income
# 294         Sub-Saharan Africa   Lower middle income
# 295         Sub-Saharan Africa   Lower middle income
#
# [296 rows x 5 columns]

# %%
gdp_le_country_final = gdp_le_df.merge(country_df,how='outer')
gdp_le_country_final
# Out:
#        Year  GDP_Per_Capita country_id  \
# 0      2023     4047.007031         ZH
# 1      2022     4038.638689         ZH
# 2      2021     3994.171654         ZH
# 3      2020     3919.499230         ZH
# 4      2019     4130.057222         ZH
# ...     ...             ...        ...
# 17051   NaN             NaN         6N
# 17052   NaN             NaN         R6
# 17053   NaN             NaN         ZG
# 17054   NaN             NaN         A4
# 17055   NaN             NaN         A5
#
#                                                  country  Life_expectancy  \
# 0                            Africa Eastern and Southern              NaN
# 1                            Africa Eastern and Southern        62.899031
# 2                            Africa Eastern and Southern        62.454590
# 3                            Africa Eastern and Southern        63.313860
# 4                            Africa Eastern and Southern        63.755678
# ...                                                  ...              ...
# 17051  IDA countries not classified as fragile situat...              NaN
# 17052         Resource rich Sub-Saharan Africa countries              NaN
# 17053                                Sub-Saharan Africa               NaN
# 17054          Sub-Saharan Africa excluding South Africa              NaN
# 17055  Sub-Saharan Africa excluding South Africa and ...              NaN
#
#       capital      region income_level
# 0              Aggregates   Aggregates
# 1              Aggregates   Aggregates
# 2              Aggregates   Aggregates
# 3              Aggregates   Aggregates
# 4              Aggregates   Aggregates
# ...       ...         ...          ...
# 17051          Aggregates   Aggregates
# 17052          Aggregates   Aggregates
# 17053          Aggregates   Aggregates
# 17054          Aggregates   Aggregates
# 17055          Aggregates   Aggregates
#
# [17056 rows x 8 columns]

# %%
#should this be dropped?
gdp_le_country_final[gdp_le_country_final['region' ] == 'Aggregates']
# Out:
#        Year  GDP_Per_Capita country_id  \
# 0      2023     4047.007031         ZH
# 1      2022     4038.638689         ZH
# 2      2021     3994.171654         ZH
# 3      2020     3919.499230         ZH
# 4      2019     4130.057222         ZH
# ...     ...             ...        ...
# 17051   NaN             NaN         6N
# 17052   NaN             NaN         R6
# 17053   NaN             NaN         ZG
# 17054   NaN             NaN         A4
# 17055   NaN             NaN         A5
#
#                                                  country  Life_expectancy  \
# 0                            Africa Eastern and Southern              NaN
# 1                            Africa Eastern and Southern        62.899031
# 2                            Africa Eastern and Southern        62.454590
# 3                            Africa Eastern and Southern        63.313860
# 4                            Africa Eastern and Southern        63.755678
# ...                                                  ...              ...
# 17051  IDA countries not classified as fragile situat...              NaN
# 17052         Resource rich Sub-Saharan Africa countries              NaN
# 17053                                Sub-Saharan Africa               NaN
# 17054          Sub-Saharan Africa excluding South Africa              NaN
# 17055  Sub-Saharan Africa excluding South Africa and ...              NaN
#
#       capital      region income_level
# 0              Aggregates   Aggregates
# 1              Aggregates   Aggregates
# 2              Aggregates   Aggregates
# 3              Aggregates   Aggregates
# 4              Aggregates   Aggregates
# ...       ...         ...          ...
# 17051          Aggregates   Aggregates
# 17052          Aggregates   Aggregates
# 17053          Aggregates   Aggregates
# 17054          Aggregates   Aggregates
# 17055          Aggregates   Aggregates
#
# [3040 rows x 8 columns]

# %% [markdown]
# **Bonus Questions:** After doing a basic request to get all records, you can attempt these exercises to get additional practice using query parameters.

# %% [markdown]
# #### 1. Adjust your request so that it returns data just for the United States.

# %%
endpoint = 'https://api.worldbank.org/v2/country/us'

params = {
    'format': 'json'
}

response = requests.get(endpoint, params = params)

res = response.json()
res
# Out:
# [{'page': 1, 'pages': 1, 'per_page': '50', 'total': 1},
#  [{'id': 'USA',
#    'iso2Code': 'US',
#    'name': 'United States',
#    'region': {'id': 'NAC', 'iso2code': 'XU', 'value': 'North America'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#    'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#    'capitalCity': 'Washington D.C.',
#    'longitude': '-77.032',
#    'latitude': '38.8895'}]]

# %% [markdown]
# #### 2. Adjust your request so that it returns data just for the United States for the year 2021.

# %%
endpoint = 'https://api.worldbank.org/v2/country/us/indicator/SP.DYN.LE00.IN'

params = {
    'format': 'json',
    'date' : 2021
}

response = requests.get(endpoint, params = params)

res = response.json()
res
# Out:
# [{'page': 1,
#   'pages': 1,
#   'per_page': 50,
#   'total': 1,
#   'sourceid': '2',
#   'lastupdated': '2024-10-24'},
#  [{'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2021',
#    'value': 76.3292682926829,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0}]]

# %% [markdown]
# ####  3. Adjust your request so that it returns data just for the United States for the years 2000 through 2021.

# %%
endpoint = 'https://api.worldbank.org/v2/country/us/indicator/SP.DYN.LE00.IN'

params = {
    'format': 'json',
    'date' : '2000:2021'
}

response = requests.get(endpoint, params = params)

res = response.json()
res
#response.url
# Out:
# [{'page': 1,
#   'pages': 1,
#   'per_page': 50,
#   'total': 22,
#   'sourceid': '2',
#   'lastupdated': '2024-10-24'},
#  [{'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2021',
#    'value': 76.3292682926829,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2020',
#    'value': 76.9804878048781,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2019',
#    'value': 78.7878048780488,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2018',
#    'value': 78.6390243902439,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2017',
#    'value': 78.5390243902439,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2016',
#    'value': 78.5390243902439,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2015',
#    'value': 78.690243902439,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2014',
#    'value': 78.8414634146341,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2013',
#    'value': 78.7414634146342,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2012',
#    'value': 78.7414634146342,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2011',
#    'value': 78.6414634146341,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2010',
#    'value': 78.5414634146342,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2009',
#    'value': 78.390243902439,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2008',
#    'value': 78.0390243902439,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2007',
#    'value': 77.9878048780488,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2006',
#    'value': 77.6878048780488,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2005',
#    'value': 77.4878048780488,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2004',
#    'value': 77.4878048780488,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2003',
#    'value': 77.0365853658537,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2002',
#    'value': 76.9365853658537,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2001',
#    'value': 76.8365853658537,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2000',
#    'value': 76.6365853658537,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0}]]

# %% [markdown]
# #### 4. Adjust your request so that it returns data for the United States and Canada for the years 2000 through 2021.

# %%
endpoint = 'https://api.worldbank.org/v2/country/us;ca/indicator/SP.DYN.LE00.IN'

params = {
    'format': 'json',
    "per_page" : 128,
    'date' : '2000:2021'
}

response = requests.get(endpoint, params = params)

res = response.json()
res
#response.url
# Out:
# [{'page': 1,
#   'pages': 1,
#   'per_page': 128,
#   'total': 44,
#   'sourceid': '2',
#   'lastupdated': '2024-10-24'},
#  [{'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2021',
#    'value': 81.5870731707317,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2020',
#    'value': 81.6604878048781,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2019',
#    'value': 82.2239024390244,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2018',
#    'value': 81.8439024390244,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2017',
#    'value': 81.8329268292683,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2016',
#    'value': 81.9248780487805,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2015',
#    'value': 81.8156097560976,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2014',
#    'value': 81.7843902439025,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2013',
#    'value': 81.7448780487805,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2012',
#    'value': 81.6636585365854,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2011',
#    'value': 81.4826829268293,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2010',
#    'value': 81.3221951219512,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2009',
#    'value': 81.0660975609756,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2008',
#    'value': 80.7246341463415,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2007',
#    'value': 80.5436585365854,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2006',
#    'value': 80.5436585365854,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2005',
#    'value': 80.1126829268293,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2004',
#    'value': 79.9921951219512,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2003',
#    'value': 79.7151219512195,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2002',
#    'value': 79.5307317073171,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2001',
#    'value': 79.3980487804878,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'CA', 'value': 'Canada'},
#    'countryiso3code': 'CAN',
#    'date': '2000',
#    'value': 79.1668292682927,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2021',
#    'value': 76.3292682926829,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2020',
#    'value': 76.9804878048781,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2019',
#    'value': 78.7878048780488,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2018',
#    'value': 78.6390243902439,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2017',
#    'value': 78.5390243902439,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2016',
#    'value': 78.5390243902439,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2015',
#    'value': 78.690243902439,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2014',
#    'value': 78.8414634146341,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2013',
#    'value': 78.7414634146342,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2012',
#    'value': 78.7414634146342,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2011',
#    'value': 78.6414634146341,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2010',
#    'value': 78.5414634146342,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2009',
#    'value': 78.390243902439,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2008',
#    'value': 78.0390243902439,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2007',
#    'value': 77.9878048780488,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2006',
#    'value': 77.6878048780488,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2005',
#    'value': 77.4878048780488,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2004',
#    'value': 77.4878048780488,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2003',
#    'value': 77.0365853658537,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2002',
#    'value': 76.9365853658537,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2001',
#    'value': 76.8365853658537,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.DYN.LE00.IN',
#     'value': 'Life expectancy at birth, total (years)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2000',
#    'value': 76.6365853658537,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0}]]

# %% [markdown]
# #### 5. If you haven't already done so and you would like to get some additional practice using loops, use the page parameter in order to pull all records. Do not change the value of the per_page parameter. You will likely need to utilize a loop of some kind in order to pull all records.

# %%
page=1
endpoint = 'https://api.worldbank.org/v2/country/'
params = {
    'format': 'json'
}
#finalData=[]
params['page'] = page

response = requests.get(endpoint, params = params)
res = response.json()
res[0]['pages']
#while(page <= 2):
#    finalData.append(res[1])
#    page = page + 1
#    params['page'] = page
#    params
#    response = requests.get(endpoint, params = params)
#    res = response.json()
#    res

#finalData
# Out:
# 6
